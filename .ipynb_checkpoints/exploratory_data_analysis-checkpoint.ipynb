# %% [markdown]
# # METIS Intro to Data Science Project

# %% [markdown]
# ## By: Ben McGauhey

# %% [markdown]
# ### Seattle, WA Fall-2017

# %% [markdown]
# # Exploratory Data Analysis
# We will start by simply loading our dataframe from the pickle file we saved it as earlier, then we will explore some of the relationships between variables and create some visualizations to better understand the data.

# %%
import pandas as pd
import numpy as np          # As Always we import our libraries
import seaborn as sns
import scipy
import matplotlib.pyplot as plt
import folium
from shapely.geometry import Point
# %matplotlib inline

# %%
df = pd.read_pickle('Data/weatherAndCallData.pkl') # Get our dataframe up and running from our saved file

# %% [markdown]
# # Getting and cleaning my data took much longer than anticipated, and the large size of the dataset had me waiting for way too long for most calculations to run, so in the interest of time, we will be selecting Homicide as our outcome and only be focusing on the effects of location and weather on homicides

# %% [markdown]
# ## Our initial instincts tell us that location probably has a greater effect than the weather on our outcome variable, so lets take a look at where our events have occured

# %%
homicideDF = df[df.homicide == 1]
homicideDF = homicideDF.iloc[:,0:3]
locations = homicideDF[['latitude', 'longitude']]
locationlist = locations.values.tolist()
len(locationlist)
# Out:
# 93

# %%
map = folium.Map(location=[47.713253, -122.355515], zoom_start=12)
for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dropCols = df.columns[4:39] # Make a mask of our other crime columns

# %%
df.drop(dropCols, axis=1, inplace=True) # Drop the other crimes from our df

# %%
homicide = df.homicide # Rearrange our df so our outcome is in the first column
df.drop('homicide', axis=1, inplace=True)
df.insert(0,'homicide', homicide)

# %%
corr = df.corr()
sns.set_style('whitegrid') # Set our style
fig, ax = plt.subplots()
fig.set_size_inches(12, 12) # Make it big enough to read the column names
sns.heatmap(corr) # Plot a heatmap

# %%
homicideCorrs = corr.iloc[:,0]
homicideCorrs.sort_values(ascending=False)
# Out:
# homicide                        1.000000
# s2                              0.005610
# g1                              0.003607
# longitude                       0.003552
# k3                              0.003466
# mist                            0.002854
# r3                              0.002794
# c3                              0.002458
# s3                              0.002364
# g3                              0.002209
# e3                              0.001796
# f3                              0.001565
# sky_is_clear                    0.001469
# o3                              0.001069
# few_clouds                      0.001047
# temp                            0.001021
# pressure                        0.001005
# light_intensity_shower_rain     0.000954
# wind_deg                        0.000854
# d3                              0.000771
# q1                              0.000734
# q3                              0.000606
# f1                              0.000581
# o2                              0.000572
# f2                              0.000485
# o1                              0.000441
# m1                              0.000413
# broken_clouds                   0.000334
# r2                              0.000196
# fog                             0.000141
#                                   ...
# u1                             -0.000802
# wind_speed                     -0.000805
# light_rain                     -0.000818
# u2                             -0.000848
# d2                             -0.000853
# light_intensity_drizzle        -0.000886
# w3                             -0.001174
# j1                             -0.001269
# m3                             -0.001274
# g2                             -0.001282
# c2                             -0.001310
# j2                             -0.001311
# l3                             -0.001317
# overcast_clouds                -0.001338
# w2                             -0.001346
# c1                             -0.001358
# n2                             -0.001359
# l2                             -0.001395
# u3                             -0.001423
# b1                             -0.001559
# e1                             -0.001653
# n3                             -0.001713
# sky_is_clear                   -0.001859
# e2                             -0.001921
# latitude                       -0.005796
# snow_today                           NaN
# squalls                              NaN
# heavy_intensity_drizzle              NaN
# thunderstorm_with_light_rain         NaN
# thunderstorm_with_rain               NaN
# Name: homicide, dtype: float64

# %%
pd.set_option('display.max_columns', 200) # Set our options so we can see some more of the data by scrolling
pd.set_option('display.max_row', 50)
print(df.columns.values)
# Out:
# ['longitude' 'latitude' 'formatted_time' 'homicide' 'robbery' 'assault'
#  'burglary' 'theft' 'car_theft' 'reckless_burning' 'fraud' 'vice'
#  'property' 'lewd_behavior' 'trespass' 'park_violation' 'liquor_violation'
#  'drive_by_shooting' 'narcotics' 'warrant_service' 'security_alarms'
#  'mental_health' 'disturbance' 'animals' 'suspicious_case'
#  'person_with_weapon' 'harbor_theft' 'casualty' 'harbor_boat_assist'
#  'harbor_dui' 'hazards' 'missing_person' 'missing_property' 'crowd_control'
#  'traffic_general' 'dui' 'traffic_minor' 'human_trafficking' '99' 'b1' 'b2'
#  'b3' 'bs' 'c1' 'c2' 'c3' 'ccd' 'comm' 'cs' 'cty' 'd1' 'd2' 'd3' 'det' 'ds'
#  'e' 'e1' 'e2' 'e3' 'ep' 'es' 'f1' 'f2' 'f3' 'fs' 'g1' 'g2' 'g3' 'gs' 'h2'
#  'h3' 'inv' 'j1' 'j2' 'j3' 'js' 'k1' 'k2' 'k3' 'kcio07' 'ks' 'l1' 'l2' 'l3'
#  'lapt' 'ls' 'm1' 'm2' 'm3' 'ms' 'n' 'n1' 'n2' 'n3' 'np' 'ns' 'o1' 'o2'
#  'o3' 'os' 'q1' 'q2' 'q3' 'qs' 'r1' 'r2' 'r3' 'rs' 's' 's1' 's2' 's3'
#  'sctr1' 'sp' 'ss' 'tac3' 'trf' 'u1' 'u2' 'u3' 'us' 'w' 'w1' 'w2' 'w3' 'wp'
#  'ws' 'temp' 'pressure' 'humidity' 'wind_speed' 'wind_deg' 'rain_today'
#  'clouds_all' 'sky_is_clear' 'broken_clouds' 'drizzle' 'few_clouds' 'fog'
#  'haze' 'heavy_intensity_rain' 'heavy_intensity_shower_rain' 'heavy_snow'
#  'light_intensity_drizzle' 'light_intensity_shower_rain' 'light_rain'
#  'light_snow' 'mist' 'moderate_rain' 'overcast_clouds'
#  'proximity_thunderstorm' 'scattered_clouds' 'shower_rain' 'sky_is_clear'
#  'smoke' 'snow' 'thunderstorm' 'very_heavy_rain']

# %%
crimeInfo = df.iloc[:,3:38] # Create some subsets of our dataframe to make specific comparisons with
beatInfo = df.iloc[:,38:-31]
wxInfo = df.iloc[:,-31:]

# %%
print(crimeInfo.expanding(min_periods=1).corr(other=wxInfo, pairwise=True))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-1e8d3b8e8970> in <module>()
# ----> 1 print(crimeInfo.expanding(min_periods=1).corr(other=wxInfo, pairwise=True))
#
# /Users/BenM/anaconda/lib/python3.6/site-packages/pandas/core/window.py in corr(self, other, pairwise, **kwargs)
#    1345     def corr(self, other=None, pairwise=None, **kwargs):
#    1346         return super(Expanding, self).corr(other=other, pairwise=pairwise,
# -> 1347                                            **kwargs)
#    1348
#    1349
#
# /Users/BenM/anaconda/lib/python3.6/site-packages/pandas/core/window.py in corr(self, other, pairwise, **kwargs)
#     994
#     995         return _flex_binary_moment(self._selected_obj, other._selected_obj,
# --> 996                                    _get_corr, pairwise=bool(pairwise))
#     997
#     998
#
# /Users/BenM/anaconda/lib/python3.6/site-packages/pandas/core/window.py in _flex_binary_moment(arg1, arg2, f, pairwise)
#    1683                         else:
#    1684                             results[i][j] = f(*_prep_binary(arg1.iloc[:, i],
# -> 1685                                                             arg2.iloc[:, j]))
#    1686                 p = Panel.from_dict(results).swapaxes('items', 'major')
#    1687                 if len(p.major_axis) > 0:
#
# /Users/BenM/anaconda/lib/python3.6/site-packages/pandas/core/window.py in _get_corr(a, b)
#     991                           freq=self.freq, center=self.center)
#     992
# --> 993             return a.cov(b, **kwargs) / (a.std(**kwargs) * b.std(**kwargs))
#     994
#     995         return _flex_binary_moment(self._selected_obj, other._selected_obj,
#
# /Users/BenM/anaconda/lib/python3.6/site-packages/pandas/core/window.py in cov(self, other, pairwise, ddof, **kwargs)
#    1155     def cov(self, other=None, pairwise=None, ddof=1, **kwargs):
#    1156         return super(Rolling, self).cov(other=other, pairwise=pairwise,
# -> 1157                                         ddof=ddof, **kwargs)
#    1158
#    1159     @Substitution(name='rolling')
#
# /Users/BenM/anaconda/lib/python3.6/site-packages/pandas/core/window.py in cov(self, other, pairwise, ddof, **kwargs)
#     961
#     962         return _flex_binary_moment(self._selected_obj, other._selected_obj,
# --> 963                                    _get_cov, pairwise=bool(pairwise))
#     964
#     965     _shared_docs['corr'] = dedent("""
#
# /Users/BenM/anaconda/lib/python3.6/site-packages/pandas/core/window.py in _flex_binary_moment(arg1, arg2, f, pairwise)
#    1642             isinstance(arg2, (np.ndarray, Series))):
#    1643         X, Y = _prep_binary(arg1, arg2)
# -> 1644         return f(X, Y)
#    1645
#    1646     elif isinstance(arg1, DataFrame):
#
# /Users/BenM/anaconda/lib/python3.6/site-packages/pandas/core/window.py in _get_cov(X, Y)
#     958                                     center=self.center).count(**kwargs)
#     959             bias_adj = count / (count - ddof)
# --> 960             return (mean(X * Y) - mean(X) * mean(Y)) * bias_adj
#     961
#     962         return _flex_binary_moment(self._selected_obj, other._selected_obj,
#
# /Users/BenM/anaconda/lib/python3.6/site-packages/pandas/core/window.py in <lambda>(x)
#     954             Y = Y.astype('float64')
#     955             mean = lambda x: x.rolling(window, self.min_periods,
# --> 956                                        center=self.center).mean(**kwargs)
#     957             count = (X + Y).rolling(window=window,
#     958                                     center=self.center).count(**kwargs)
#
# /Users/BenM/anaconda/lib/python3.6/site-packages/pandas/core/window.py in mean(self, *args, **kwargs)
#    1110     def mean(self, *args, **kwargs):
#    1111         nv.validate_rolling_func('mean', args, kwargs)
# -> 1112         return super(Rolling, self).mean(*args, **kwargs)
#    1113
#    1114     @Substitution(name='rolling')
#
# /Users/BenM/anaconda/lib/python3.6/site-packages/pandas/core/window.py in mean(self, *args, **kwargs)
#     839     def mean(self, *args, **kwargs):
#     840         nv.validate_window_func('mean', args, kwargs)
# --> 841         return self._apply('roll_mean', 'mean', **kwargs)
#     842
#     843     _shared_docs['median'] = dedent("""
#
# /Users/BenM/anaconda/lib/python3.6/site-packages/pandas/core/window.py in _apply(self, func, name, window, center, check_minp, how, **kwargs)
#     693             check_minp = _use_window
#     694
# --> 695         blocks, obj, index = self._create_blocks(how=how)
#     696         index, indexi = self._get_index(index=index)
#     697         results = []
#
# /Users/BenM/anaconda/lib/python3.6/site-packages/pandas/core/window.py in _create_blocks(self, how)
#     130                 obj = obj.reindex(columns=obj.columns.difference([self.on]),
#     131                                   copy=False)
# --> 132         blocks = obj.as_blocks(copy=False).values()
#     133
#     134         return blocks, obj, index
#
# /Users/BenM/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in as_blocks(self, copy)
#    2995             # Must combine even after consolidation, because there may be
#    2996             # sparse items which are never consolidated into one block.
# -> 2997             combined = self._data.combine(blocks, copy=copy)
#    2998             result[dtype] = self._constructor(combined).__finalize__(self)
#    2999
#
# /Users/BenM/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in combine(self, blocks, copy)
#    3331
#    3332         axes = list(self.axes)
# -> 3333         axes[0] = self.items.take(indexer)
#    3334
#    3335         return self.__class__(new_blocks, axes, do_integrity_check=False)
#
# /Users/BenM/anaconda/lib/python3.6/site-packages/pandas/indexes/base.py in take(self, indices, axis, allow_fill, fill_value, **kwargs)
#    1518                 msg = 'Unable to fill values because {0} cannot contain NA'
#    1519                 raise ValueError(msg.format(self.__class__.__name__))
# -> 1520             taken = self.values.take(indices)
#    1521         return self._shallow_copy(taken)
#    1522
#
# KeyboardInterrupt:
